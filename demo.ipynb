# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
from signature_detect.loader import Loader
from signature_detect.extractor import Extractor
from signature_detect.cropper import Cropper
from signature_detect.judger import Judger

# %load_ext autoreload
# %autoreload 2

# %%
def show_image(img):
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.imshow(img)
    ax.set_axis_off()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Image

# %%
path = './data/input/signed_image.jpeg'
image = cv2.imread('./data/input/signed_image.jpeg')
show_image(image)

# %% [markdown]
# ## Loader
#
# The loader reads the file and creates a mask.
#
# The mask is a numpy array. The bright parts are set to 255, the rest is set to 0.

# %%
loader = Loader()
print(loader)
# Out:
# Loader
# ==========
# low_threshold = (0, 0, 250)
# high_threshold = (255, 255, 255)

# %%
mask = loader.get_masks(path)[0]
print(mask)
print(np.unique(mask))
show_image(mask)
# plt.imsave('./data/output/mask.jpeg', mask)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# [  0 255]

# %% [markdown]
# ## Extractor
#
# The extractor
#
# 1. generates the regions from the mask.
# 2. removes the small and the big region because the signature is neither too big nor too small.

# %%
extractor = Extractor(amplfier=15)
print(extractor)
# Out:
# Extractor
# ==========
# outlier_weight = 3
# outlier_bias = 100
# > small_outlier_size = outlier_weight * average_region_size + outlier_bias
# amplfier = 15
# > large_outlier_size = amplfier * small_outlier_size
# min_area_size = 10 (pixels)
# > min_area_size is used to calculate average_region_size.

# %%
labeled_mask = extractor.extract(mask)
print(np.unique(labeled_mask))
show_image(labeled_mask)
# plt.imsave('./data/output/labeled_mask.jpeg', labeled_mask)
# Out:
# [  0 255]

# %% [markdown]
# ## Cropper
#
# The cropper finds the **contours** of regions in the **labeled masks** and crop them.

# %%
cropper = Cropper()
print(cropper)
# Out:
# Cropper
# ==========
# min_region_size = 10000
# border_ratio = 0.1

# %%
results = cropper.run(labeled_mask)

# %%
signature = results[0]["cropped_mask"]
print(np.unique(signature))
show_image(signature)
# plt.imsave('./data/output/signature.jpeg', signature)
# Out:
# [  0 255]

# %% [markdown]
# ## Judger
#
# The judger reads the cropped mask and identifies if it's a signature or not.

# %%
judger = Judger()
print(judger)
# Out:
# Judger
# ==========
# size_ratio = [1, 4]
# pixel_ratio = [0.01, 1]

# %%
result = judger.judge(signature)
result
# Out:
# True

# %% [markdown]
# # PDF

# %%
file_path = './data/input/signed_file.pdf'
loader = Loader()
extractor = Extractor(amplfier=15)
cropper = Cropper(border_ratio=0)
judger = Judger()

# %%
masks = loader.get_masks(file_path)
for i in range(len(masks)):
    show_image(masks[i])
    # plt.imsave('./data/output/mask_{}.jpeg'.format(i), masks[i])
# Out:
# ---------------------------------------------------------------------------
# DelegateError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_448\3019509749.py in <module>
# ----> 1 masks = loader.get_masks(file_path)
#       2 for i in range(len(masks)):
#       3     show_image(masks[i])
#       4     # plt.imsave('./data/output/mask_{}.jpeg'.format(i), masks[i])
#
# ~\AppData\Roaming\Python\Python39\site-packages\signature_detect\loader.py in get_masks(self, path)
#      64         if self.document_type == "PDF":
#      65             loader = _PdfWorker(self.low_threshold, self.high_threshold)
# ---> 66             return loader.get_pdf_masks(path)
#      67
#      68
#
# ~\AppData\Roaming\Python\Python39\site-packages\signature_detect\loader.py in get_pdf_masks(self, path)
#     113         page by page
#     114         """
# --> 115         images = self.get_pdf_images(path)
#     116
#     117         masks = []
#
# ~\AppData\Roaming\Python\Python39\site-packages\signature_detect\loader.py in get_pdf_images(self, path)
#     101     def get_pdf_images(self, path: str) -> list:
#     102         imgs = []
# --> 103         with(Image(filename=path,resolution=200)) as source:
#     104             images=source.sequence
#     105             pages=len(images)
#
# ~\AppData\Roaming\Python\Python39\site-packages\wand\image.py in __init__(self, image, blob, file, filename, pseudo, background, colorspace, depth, extract, format, height, interlace, resolution, sampling_factors, units, width)
#    9363                     self.read(blob=blob)
#    9364                 elif filename is not None:
# -> 9365                     self.read(filename=filename)
#    9366                 # clear the wand format, otherwise any subsequent call to
#    9367                 # MagickGetImageBlob will silently change the image to this
#
# ~\AppData\Roaming\Python\Python39\site-packages\wand\image.py in read(self, file, filename, blob, background, colorspace, depth, extract, format, height, interlace, resolution, sampling_factors, units, width)
#   10118             r = library.MagickReadImage(self.wand, filename)
#   10119         if not r:
# > 10120             self.raise_exception()
#   10121             msg = ('MagickReadImage returns false, but did not raise '
#   10122                    'ImageMagick  exception. This can occur when a delegate '
#
# ~\AppData\Roaming\Python\Python39\site-packages\wand\resource.py in raise_exception(self, stacklevel)
#     223             warnings.warn(e, stacklevel=stacklevel + 1)
#     224         elif isinstance(e, Exception):
# --> 225             raise e
#     226
#     227     def make_blob(self, format=None):
#
# DelegateError: FailedToExecuteCommand `"gswin64c.exe" -q -dQUIET -dSAFER -dBATCH -dNOPAUSE -dNOPROMPT -dMaxBitmap=500000000 -dAlignToPixels=0 -dGridFitTT=2 "-sDEVICE=pngalpha" -dTextAlphaBits=4 -dGraphicsAlphaBits=4 "-r200x200" -dPrinted=false  "-sOutputFile=C:/Users/iwano/AppData/Local/Temp/magick-UD7-DEBtUHYeP518WOf25bC7gFpBLrLo%d" "-fC:/Users/iwano/AppData/Local/Temp/magick-gepcVoZJQdApre0u79Oad5nAfuxcNTyP" "-fC:/Users/iwano/AppData/Local/Temp/magick-4_9p1pCgEcVDU4610E61zOc9sv0LcVFc"' (Nie mo�na odnale�� okre�lonego pliku.
# ) @ error/delegate.c/ExternalDelegateCommand/517

# %%
is_signed = False
for i in range(len(masks)):
    labeled_mask = extractor.extract(masks[i])
    show_image(labeled_mask)
    # plt.imsave('./data/output/labeled_mask_{}.jpeg'.format(i), labeled_mask)
    results = cropper.run(labeled_mask)
    for result in results.values():
        is_signed = judger.judge(result["cropped_mask"])
        if is_signed:
            show_image(result["cropped_mask"])
            # plt.imsave('./data/output/sign.jpeg'.format(i), cropped_image)
            break
    if is_signed:
        break
print(is_signed)
# Out:
# True
